# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data.csv', 'pipeline.ipynb', 'processed_data.csv']

# %%
def etl_pipeline(input_file, output_file):
    import pandas as pd
    import os
    from sklearn.preprocessing import StandardScaler, LabelEncoder
    print("🚀 Starting ETL Pipeline...\n")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data.csv', 'pipeline.ipynb', 'processed_data.csv']

# %%
df=pd.read_csv(r"C:\Users\Administrator\Downloads\archive (2)\NetFlix.csv")

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
df.tail()
# Out:
#      show_id     type                      title             director  \
# 7782    s995  TV Show                 Blown Away                  NaN
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast  \
# 7782                                                NaN
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# ...

# %%
df.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
df = df[['title', 'type', 'country', 'release_year', 'rating']]

# %%
print(df)
# Out:
#                                           title     type  \
# 0                                            3%  TV Show
# 1                                          1920    Movie
# 2                                    3 Heroines    Movie
# 3     Blue Mountain State: The Rise of Thadland    Movie
# 4                                Blue Planet II  TV Show
# ...                                         ...      ...
# 7782                                 Blown Away  TV Show
# 7783                              Blue Exorcist  TV Show
# 7784                  Blue Is the Warmest Color    Movie
# 7785                               Blue Jasmine    Movie
# 7786                                   Blue Jay    Movie
#
#                      country  release_year rating
# 0                     Brazil          2020  TV-MA
# 1                      India          2008  TV-MA
# 2                  Indonesia          2016  TV-PG
# 3              United States          2016      R
# ...

# %%
def etl_pipeline(input_file, output_file):
    import pandas as pd
    from sklearn.preprocessing import LabelEncoder, StandardScaler

    print("🚀 Starting ETL Pipeline...\n")

    # 🔷 STEP 1: EXTRACT (Load Data)
    df = pd.read_csv(input_file)
    print("✅ Data Loaded")
    print("Shape:", df.shape)
    print("-" * 40)

    # 🔷 STEP 2: Select Required Columns
    df = df[['title', 'type', 'country', 'release_year', 'rating']]
    print("✅ Columns Selected")
    print("-" * 40)

    # 🔷 STEP 3: Handle Missing Values
    df['country'] = df['country'].fillna("Unknown")
    df['rating'] = df['rating'].fillna("Not Rated")
    print("✅ Missing Values Handled")
    print(df.isnull().sum())
    print("-" * 40)

    # 🔷 STEP 4: Remove Duplicates
    df.drop_duplicates(inplace=True)
    print("✅ Duplicates Removed")
    print("Shape after cleaning:", df.shape)
    print("-" * 40)

    # 🔷 STEP 5: Encode Categorical Columns
    le = LabelEncoder()
    df['type'] = le.fit_transform(df['type'])
    df['country'] = le.fit_transform(df['country'])
    df['rating'] = le.fit_transform(df['rating'])
    print("✅ Encoding Done")
    print("-" * 40)

    # 🔷 STEP 6: Handle Outliers (on release_year)
    q1 = df['release_year'].quantile(0.25)
    q3 = df['release_year'].quantile(0.75)
    iqr = q3 - q1

    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr

    df = df[(df['release_year'] >= lower) & (df['release_year'] <= upper)]

    print("✅ Outliers Removed")
    print("Shape after outlier removal:", df.shape)
    print("-" * 40)

    # 🔷 STEP : Scale Numerical Column
    scaler = StandardScaler()
    df[['release_year']] = scaler.fit_transform(df[['release_year']])
    print("✅ Scaling Done")
    print("-" * 40)
    print("🔷 Data Types:\n", df.dtypes)

    # 🔷 STEP 7: Final Check
    print("📊 Final Shape:", df.shape)
    print("📊 Missing Values:\n", df.isnull().sum())
    print("-" * 40)

    # 🔷 STEP 8: LOAD (Save Data)
    df.to_csv(output_file, index=False)
    print("📁 Data saved to:", output_file)

    print("\n🎉 ETL Pipeline Completed Successfully!")

    return df
# Out:
#   File <tokenize>:48
#     print("✅ Outliers Removed")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
etl_pipeline("data.csv", "processed_data.csv")
# Out:
# 🚀 Starting ETL Pipeline...
#
# ✅ Data Loaded
# Shape: (7787, 12)
# ----------------------------------------
# ✅ Columns Selected
# ----------------------------------------
# ✅ Missing Values Handled
# title           0
# type            0
# country         0
# release_year    0
# rating          0
# dtype: int64
# ----------------------------------------
# ✅ Duplicates Removed
# Shape after cleaning: (7787, 5)
# ----------------------------------------
# ✅ Encoding Done
# ----------------------------------------
# ✅ Scaling Done
# ----------------------------------------
# 🔷 Data Types:
#  title            object
# type              int64
# country           int64
# release_year    float64
# rating            int64
# dtype: object
# 📊 Final Shape: (7787, 5)
# 📊 Missing Values:
#  title           0
# type            0
# country         0
# release_year    0
# rating          0
# dtype: int64
# ----------------------------------------
# 📁 Data saved to: processed_data.csv
#
# ...
